# %%
import pandas as pd
import numpy as np
from windows import get_window

df = pd.read_csv("shingles.congress")
aa = df[df["fn"] == "demos/hr_201.anno"]
bb = df[df["fn"] == "demos/hr_202.anno"]
pd.merge(aa, bb, on='digit', how='inner')
# Out:
#                      fn_x                                  digit  window_no_x  \
# 0       demos/hr_201.anno   676973006321235974393162029485547328          160
# 1       demos/hr_201.anno   676973006321235974393162029485547328          160
# 2       demos/hr_201.anno   676973006321235974393162029485547328          160
# 3       demos/hr_201.anno   676973006321235974393162029485547328          160
# 4       demos/hr_201.anno   676973006321235974393162029485547328          160
# 5       demos/hr_201.anno   676973006321235974393162029485547328          160
# 6       demos/hr_201.anno   676973006321235974393162029485547328          160
# 7       demos/hr_201.anno   676973006321235974393162029485547328          160
# 8       demos/hr_201.anno   676973006321235974393162029485547328          160
# 9       demos/hr_201.anno   676973006321235974393162029485547328          160
# 10      demos/hr_201.anno   676973006321235974393162029485547328          160
# ...

# %%
" ".join(get_window("demos/hr_201.anno", 50, 10814))
# Out:
# u'on the implementation and impact of the plan developed under subsection -LRB- a -RRB- . SEC . 213 . FUNDING . From amounts made available for Federal purposes under section 5 of the Land and Water Conservation Fund Act of 1965 -LRB- 16 U.S.C. 460l-7 -RRB- , there is authorized'

# %%
" ".join(get_window("demos/hr_202.anno", 50,1552))
# Out:
# u'the House of Representatives and the Committee on Banking , Housing , and Urban Affairs and the Committee on Environment and Public Works of the Senate a report on the implementation and impact of the plan developed under subsection -LRB- a -RRB- . -LRB- 11 -RRB- According to the Juvenile'
